# %% [markdown]
# # Python Method - Class, Objects and Functions in Python

# %% [markdown]
# ## Python Method - Objective

# %% [markdown]
# ![Methods-in-Python.jpg](attachment:Methods-in-Python.jpg)

# %% [markdown]
# ## Introduction to Python Method

# %% [markdown]
# As we aware of the fact that python is an object-oriented language, right? This means that it can deal with classes and objects to model the real world.

# %% [markdown]
# A python method is a label that we can call on an object; it is a piece of code to execute on that object. But before we begin getting any deeper, let'

# %% [markdown]
# ## Python Class Method
