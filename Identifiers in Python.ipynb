# %% [markdown]
# # Identifiers in Python - Naming Rules & Best Practices

# %% [markdown]
# ## 1. Objective

# %% [markdown]
# #### We will learn about identifiers in python and how to name them Moreover, we will see the rules, best practices, reserved classes in python identifier. Also we will test the validity of identifiers in python

# %% [markdown]
# ![Identifiers-in-Python-01.jpg](attachment:Identifiers-in-Python-01.jpg)

# %% [markdown]
# #### An identifier is a user-defined name to represent a variable, a function, a class, a module, or any other object

# %% [markdown]
# ## 2. Testing the validity of identifiers in python

# %% [markdown]
# #### while it is great to follow the rules and guidelines, we can test an identifier's validity just to be sure.

# %% [markdown]
# key.iskeyword(s)--> if s is a python keyword, return true

# %% [markdown]
# #### keyword.kwlist --> Return a sequence holding all keyword the interpreter understands. this includes even those that are active only when certain __future__ statements are in effect

# %%
import keyword

# %%
keyword.iskeyword('_$$_')
# Out:
# False

# %%
keyword.iskeyword('print()')
# Out:
# False

# %%
keyword.iskeyword('return')
# Out:
# True

# %% [markdown]
# #### Also the str.isidentifier() function will tell us if a string is a valid identifier. This is available since python 3.0

# %%
'__$$__'.isidentifier()
# Out:
# False
