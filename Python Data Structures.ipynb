# %% [markdown]
# # Python Data Structures - Lists, Tuples, Sets, Dictionaries.

# %% [markdown]
# #### We will talk about different data structures in Python provides us with. These include python list, python tuple, python set, and python dictionarie.

# %% [markdown]
# ![Python-Data-Structures.jpg](attachment:Python-Data-Structures.jpg)

# %% [markdown]
# #### We can think of a data structure as a way of organizing and storing data such that we can access and modify it efficently. Earlier, we have seen primitive data type like integers, floats, booleans and strings. Now we will take a deeper look at non primitive python data structure
