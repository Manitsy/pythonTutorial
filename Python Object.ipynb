# %% [markdown]
# # Python Object : How to create, Delete & Initializw object

# %% [markdown]
# ![Python-Objects-01.jpg](attachment:Python-Objects-01.jpg)

# %% [markdown]
# To prove our point that everything in python is an object, we will first take some example.

# %%
type(7)
# Out:
# int

# %%
a=[1,2,3]

# %%
type(a)
# Out:
# list

# %%
def sayhi():
    print("Hello")

# %%
sayhi
# Out:
# <function __main__.sayhi()>

# %%
a=True

# %%
type(a)
# Out:
# bool

# %%
type("True")
# Out:
# str

# %%
class fruit:
    pass

# %%
fruit
# Out:
# __main__.fruit

# %% [markdown]
# see the point? This is because every class is derived from the class 'object'

# %% [markdown]
# **An object is any real-world entity that has attributes and behaviors. Honestly, an object is to a class as is a prototype to a blueprint**

# %% [markdown]
# ### Python Object Initialization

# %% [markdown]
# When we create object for a class, the **\__init__()** method is called

# %%
class fruit:            
        def __init__(self,color,shape):
            self.color=color 
            self.shape=shape
        def sayhi(self):         
               print(f"Hi.\nI am {self.color} and {self.shape}")

# %%
orange = fruit('Orange','Round')

# %%
orange.sayhi()
# Out:
# Hi.
# I am Orange and Round

# %% [markdown]
# Here **\__init__()** has two attributes apart from 'self' i.e color and shape. Then, we pass corresponding arguments for these at the time of object creation

# %% [markdown]
# However, if you don’t supply the **\__init__()** method, Python will use a default one for you.

# %%
class Person:
    def sayhi(self):
        print("Hi")

# %%
Hannah = Person()

# %%
Hannah.sayhi()
# Out:
# Hi

# %% [markdown]
# ## Assigning One object to another python object

# %%
Miley=Hannah

# %%
Miley.sayhi()
# Out:
# Hi

# %%
type(Miley)
# Out:
# __main__.Person

# %%
id(Miley)
# Out:
# 4419256976

# %%
id(Hannah)
# Out:
# 4419256976

# %%
hash(Miley)
# Out:
# 276203561

# %%
hash(Hannah)
# Out:
# 276203561

# %% [markdown]
# We assigned Hannah to Miley. Now, what if we delete Hannah? How does it affect Miley?

# %%
del Hannah

# %%
Miley

# %%
Manish = Person()

# %%
Anamika = Person()

# %%
id(Manish)
# Out:
# 4419256912

# %%
id(Anamika)
# Out:
# 4419235088

# %% [markdown]
# ## Assigning Attributes to an object on the fly

# %%
orange.size=7

# %%
orange.size
# Out:
# 7

# %% [markdown]
# ## Delete Python Object?

# %%
del orange

# %%
orange
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-69c4fc8b8383> in <module>
# ----> 1 orange
#
# NameError: name 'orange' is not defined
