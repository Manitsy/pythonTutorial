# %% [markdown]
# # Chapter 2: Python Variables and Data Types

# %% [markdown]
# ### Python is a dynamically-typed language, we don’t specify the type of a variable when declaring one

# %% [markdown]
#     We will also learn about converting one data type to another in Python and local and global variables in Python. So, let’s begin with Python variables and data types Tutorial

# %% [markdown]
# ### What are Python Variables?

# %% [markdown]
#     A variable is a container for a value. It can be assigned a name, you can use it to refer to it later in the program. Based on the value assigned, the interpreter decides its data type. You can always store a different type in a variable.

# %% [markdown]
# ![python-variables-2-1.jpg](attachment:python-variables-2-1.jpg)

# %% [markdown]
# ### 1. Python Variables Naming Rules

# %% [markdown]
# There are certain rules to what we can name a variable (called an identifier)

# %% [markdown]
# #### A: Python variables can only begin with a letter(A-Z/a-z) or an underscore(_).

# %%
9lives = 9
# Out:
#   File "<ipython-input-2-8809f2c05811>", line 1
#     9lives = 9
#          ^
# SyntaxError: invalid syntax

# %%
flag = 0
flag
# Out:
# 0

# %%
_9lives='cate'

# %%
_9lives
# Out:
# 'cate'

# %% [markdown]
# B: Rest of the identifier may contain letters, underscores and number

# %%
year2 = 'sophomore'
year2
# Out:
# 'sophomore'

# %% [markdown]
# C: Python is case-sensitive, so are python identifiers. Name and name are two different identifiers

# %% [markdown]
# D: Reserved words (keywords) cannot be used as identifier names

# %% [markdown]
# ![Screen%20Shot%202020-04-05%20at%204.54.46%20PM.png](attachment:Screen%20Shot%202020-04-05%20at%204.54.46%20PM.png)

# %% [markdown]
# ### 2: Assigning and reassigning python variables

# %% [markdown]
# TO assign a value to python variables, you dont need to declare its type.

# %%
age=7
print(age)
# Out:
# 7

# %%
age='Dinosaur'
print(age)
# Out:
# Dinosaur

# %% [markdown]
# However, age=Dinosaur doent make sense. Also, we cant use python variables before assigning its value

# %%
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9bc0cb2ed6de> in <module>
# ----> 1 name
#
# NameError: name 'name' is not defined

# %% [markdown]
# ### 3. Multiple Assignment

# %% [markdown]
# we can assign values to multiple python vaiables in one statement

# %%
age, city = 21, 'Patna'

# %%
print(age,city)
# Out:
# 21 Patna

# %%
print(age)
# Out:
# 21

# %%
print(city)
# Out:
# Patna

# %% [markdown]
# We can assign the same value to multipe python variable

# %% [markdown]
# ### 4. Swapping variable

# %% [markdown]
# Swapping means interchanging values. To swap python variable, we dont need to do much

# %%
a, b = 'red', 'blue'

# %%
a,b = b,a

# %%
print(a,b)
# Out:
# blue red

# %% [markdown]
# ### 5. Deleting variables

# %% [markdown]
# We can also delete Python variables using the keyword 'del'.

# %%
a= 'red'
print(a)
# Out:
# red

# %%
del a

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-bca0e2660b9f> in <module>
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# This is how we can delete python variables

# %% [markdown]
# ![python-variable-and-data-types.jpg](attachment:python-variable-and-data-types.jpg)

# %% [markdown]
# # Python Data Types

# %% [markdown]
# Although we dont have declare a type for Python variables, a values does have a type.
# This information is vital to the interpreter. Python supports the following Python data types.

# %% [markdown]
# ## 1. Python numbers

# %% [markdown]
# there are 4 numeric Python data types

# %% [markdown]
# ### 1.1 int

# %% [markdown]
#     int stands for integer. This Python Data type holds signed integers. We can use type() function to find which class it belongs to.

# %%
a = 7
type(a)
# Out:
# int

# %% [markdown]
# ### 1.2 Float

# %% [markdown]
#     This python data type hold floating-point real values. An int can only store the number 3, but float can store 3.25 if we want

# %%
a = 3.4
type(a)
# Out:
# float

# %% [markdown]
# ### 1.3 long

# %% [markdown]
#     This python data type holds a long integer of unlimited length. But this construct doesnt exit in python 3.x

# %% [markdown]
# ### 1.4 complex

# %% [markdown]
# This python data type holds a complex number. A complex number look like this: a+bj . Here a and b are the real parts of the number, and j is imaginary.

# %%
a=2+3j
type(a)
# Out:
# complex

# %%
print(a)
# Out:
# (2+3j)

# %%
b=4+5z
# Out:
#   File "<ipython-input-28-6fc845cbbbe8>", line 1
#     b=4+5z
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### <class 'complex'>

# %% [markdown]
# Use the isinstance()function to tell if python variables belong to a particular class.
# it take two parameters-the variable/value, and the class

# %%
print(isinstance(a,complex))
# Out:
# True

# %% [markdown]
# ## 2. String

# %% [markdown]
# A string is a sequence of characters. Python does not have a char data type, unlike C++ or Java. You can delimit a string using single quotes or double quotes.

# %%
city = 'Patna'

# %%
city
# Out:
# 'Patna'

# %%
city = "Anish"
city
# Out:
# 'Anish'

# %% [markdown]
# ### 2.1 Spanning a string across lines

# %% [markdown]
# To span a string across multiple lines, you can use triple quotes

# %%
var = """ if
only """

# %%
var
# Out:
# ' if\nonly '

# %%
print (var)
# Out:
#  if
# only

# %%
var = "if \n only"

# %%
print(var)
# Out:
# if
#  only

# %%
var
# Out:
# 'if \n only'

# %% [markdown]
# ## 2.2 Displaying Part of a String

# %%
lesson = 'disappointment'

# %%
lesson[0]
# Out:
# 'd'

# %% [markdown]
# we can display a character from a string using its index in the string. Remember, indexing start with 0

# %% [markdown]
# we can also display a burst of characters in a string using the slicing operator[].

# %%
lesson[5:10]
# Out:
# 'point'

# %% [markdown]
# This prints the characters from 5 to 9

# %% [markdown]
# ## 2.3. String Formatters

# %% [markdown]
# ### String formatters allow us to print characters and values at once. You can use the % operator.

# %%
x = 10
printer = "Dell"
print("I just printed %s pages to the printer %s"  % (x, printer))
# Out:
# I just printed 10 pages to the printer Dell

# %% [markdown]
# ### Or we can use the format method

# %%
print("I just printed {0} pages to the printer {1} ".format(x, printer))
# Out:
# I just printed 10 pages to the printer Dell

# %%
print("I just printed {x} pages to the printer {printer}".format(x=7, printer='Dell'))
# Out:
# I just printed 7 pages to the printer Dell

# %%
print(f"i just printed {x} pages to the printer {printer}")
# Out:
# i just printed 10 pages to the printer Dell

# %% [markdown]
# ## 2.4 String Concatenation

# %% [markdown]
# ### We can concatenate(join) string

# %%
a='10'

# %%
type(a)
# Out:
# str

# %%
print(a+a)
# Out:
# 1010

# %% [markdown]
# ### However, we cannot concatenate values of different data types

# %%
print('10'+10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-308a455eb55d> in <module>
# ----> 1 print('10'+10)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## 3. Python Lists

# %% [markdown]
# ### A list is a collection of values. Remember, it may contain different types of values. To define list, we must put values sepatated with commas in square brackets. We dont need to declare type for a list either

# %%
days = ['Monday', 'Tuesday', 3,4,5,6,7]

# %%
days
# Out:
# ['Monday', 'Tuesday', 3, 4, 5, 6, 7]

# %%
print(days)
# Out:
# ['Monday', 'Tuesday', 3, 4, 5, 6, 7]

# %% [markdown]
# ## 3.1 Slicing a List

# %% [markdown]
# ### We can slice a list the way we did slice a string- with the slicing operator.

# %%
days[1:3]
# Out:
# ['Tuesday', 3]

# %% [markdown]
# ### Indexing for a list begins with 0, like for a strig. A python doesnt have arrays.
