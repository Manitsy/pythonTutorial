# %% [markdown]
# # Learn How To Make Python Pattern Programs With Examples

# %% [markdown]
# ![1_xirHnHmmq5w6xXGMl1qrag.png](attachment:1_xirHnHmmq5w6xXGMl1qrag.png)

# %% [markdown]
# #### Python programming langauage is quite easy to learn. The implementation of various libraries with the ease of syntax makes it stand out, one of the many reasons why it has become he most popular programing language in this decade.

# %% [markdown]
# #### While the learning part is easy, the interviewrs often seek your approach in building the logic for pattern programs. As tricky as it may sound, with python it is a piece of cake.

# %% [markdown]
# #### The following topics are covered in this are as below

# %% [markdown]
#  Star pattern Programs:
#
#      1. Pyramid Pattern Program
#      2. Half-Pyramid Patten Program
#      3. Diamond Shaped pattern program
#      4. Start pattern program
#      5. Hourglass pattern program

# %% [markdown]
#  Number pattern Programs:
#
#      1. Simple numbers in a pyramid
#      2. Pascal's Triangle Pattern
#      3. Diamond Shaped pattern program

# %% [markdown]
#  Characters pattern Programs:
#
#      1. Pyramid Pattern Program
#      2. Half-Pyramid Patten Program
#      3. Diamond Shaped pattern program
#      4. Start pattern program
#      5. Hourglass pattern program

# %% [markdown]
# ### Star Pattern Programs

# %% [markdown]
# #### 1. Pyramid Pattern Program

# %%
# Tips
for i in range(0,4):
    print((2*i)-2)
# Out:
# -2
# 0
# 2
# 4

# %%
n=5
k = 2 * n - 2
for i in range(0,n):
    #for j in range(0,k):
          #print(end=" ")
    #k = k - 1
    for j in range(0, i+1):
         print("*", end=" ")
    print("\r")
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
