# %% [markdown]
# # Python Syntax - Take your first step in the python world

# %% [markdown]
# ### The code in any language must follow a set of rules

# %% [markdown]
# ### Today, we will learn about the Python syntax in which, we will see what is Python syntax and how it is different to java and c++. After reading this article, you will be able to identify and debug Python syntax

# %% [markdown]
# ## What is Python Syntax?

# %% [markdown]
# ### The term syntax is referred to a set of rules and principles that describe the structure of a language. The Python syntax defines all the set of rules that are used to create sentences in Python Programming.

# %% [markdown]
# ### For example -
# #### We have to learn grammer when we want to learn the English language. In the same way , you will need to learn and understand the python syntax in order to learn the python language.

# %%
#simple python program to see if a user is eligible to vote or not.

# getting user's name 
print ("Enter your name:")
name = input()
print(name)
# Out:
# Enter your name:
# Manish
# Manish

# %% [markdown]
# ## Types of Syntax Structures in Python

# %% [markdown]
# ![Python-syntax.jpg](attachment:Python-syntax.jpg)

# %% [markdown]
# ### 1. Python Line Structure

# %% [markdown]
# ### A Python program comprises logical lines. A NEWLINE token follows each of those. The interpreter ignore blank line.

# %%
print("Hi
How are you")
# Out:
#   File "<ipython-input-4-726f8b1ea499>", line 1
#     print("Hi
#              ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# ## 2. Python Multiline Statements

# %% [markdown]
# #### This one is an important Python syntax. We saw that Python doesnt mandate semicolons. A new line means a new statement. But sometimes, you may want to split a statement oover two or more lines. It may be to aid readability. You can do so in the following ways

# %% [markdown]
# ### 2.1 Use a backward slash

# %%
print("Hi \
how are you")
# Out:
# Hi how are you

# %% [markdown]
# #### You can also use it to distribute a statement without a string across lines.

# %%
a \
= \
10
print(a)
# Out:
# 10

# %% [markdown]
# ### 2.2 Put the string in Triple Quotes

# %%
print (""" Hi
how are you?""")
# Out:
#  Hi
# how are you?

# %% [markdown]
# #### Howerver, you cant use backslashes inside a docstring for statements that arent a string

# %%
"""b\
=\
10"""
# Out:
# 'b=10'

# %%
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-67e500defa1b> in <module>
# ----> 1 print(b)
#
# NameError: name 'b' is not defined

# %% [markdown]
# ## 3. Python Comments

# %% [markdown]
# #### Python syntax 'comments' let you store tags at the right places in the code. You can use them to explain complex sections of code. The interpreter ignore comments. Declare a comment using an octothorpe(#).

# %%
# This is comment

# %% [markdown]
# #### Python doesnt support general multiline comments like Java or c++

# %% [markdown]
# ## 4. Python Docstrings

# %% [markdown]
# #### A docstring is a documentation string. As a comment, this python syntax is used to explain code. But unlike comments, they are more specific. Also they are retained at runtime. This way, the programmer can inspect them at runtime. Delimit a docstring using three dobule-quotes. You may put it as a function's first line to describe it.

# %%
def func():
    """
        This function prints out a greeting
    """
    print("Hi")

# %%
func()
# Out:
# Hi

# %%
help(func)
# Out:
# Help on function func in module __main__:
#
# func()
#     This function prints out a greeting

# %% [markdown]
# ### 5 Python Identation

# %% [markdown]
# #### Since Python doesnt use curly braces to delimit blocks of code, this python syntax is mandorty. You can indent code under a function, loop or class.

# %%
if 2>1:
    print("2 is bigger person");
    print("But 1 is worthly too");
# Out:
# 2 is bigger person
# But 1 is worthly too

# %% [markdown]
# #### You can indent using a number of tabs or spaces, or a combination of those. But remember, indent statements under one block of code with the same amount of tabs and spaces.

# %%
if 2>1:
    print("2 is bigger person");
        print("But 1 is worthly too");
# Out:
#   File "<ipython-input-25-a44374689d54>", line 3
#     print("But 1 is worthly too");
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ### 6 Python multiple statement in One line.

# %% [markdown]
# #### We can also fit in more than one statement on one line. Do this by separating them with a semicolon. But you'd only want to do so if it supplements readabitity

# %%
a=7 ; print(a);
# Out:
# 7

# %%
b=7 print(b)
# Out:
#   File "<ipython-input-27-ecd0a1725d5e>", line 1
#     b=7 print(b)
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 7. Python Quotations

# %% [markdown]
# #### Python supports the single quote and the double quote for string literals. But if you begin a string with a single quote, you must end it with a single quote. The same goes for double-quotes.

# %%
print("We need a chaperone")
# Out:
# We need a chaperone

# %%
print('We need a chaperone')
# Out:
# We need a chaperone

# %%
print("We need a 'chaperone'")
# Out:
# We need a 'chaperone'

# %%
print('We need a 'chaperone'')
# Out:
#   File "<ipython-input-31-a721e18b0c41>", line 1
#     print('We need a 'chaperone'')
#                               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 8. Python Blank Lines.

# %% [markdown]
# #### If you leave a line with just whitespace, the interpreter will ignore it.

# %% [markdown]
# ### 9. Pythin indentifers.

# %% [markdown]
# #### An identifier is a name of program element, and it is user-defined. This python syntax uniquely identifies the element, there are some rules to follow while choosing an identifier.

# %% [markdown]
# #### 1. An identifier may only begin with A-Z, a-z, or an underscore(_).
# #### 2. This may be followed by letters, digits, and underscores- zero or more.
# #### 3. Python is case-sensitive. Name and name are two different identifiers.
# #### 4. A reserved keyword may not be used as an identifier. The following is a list of keywords.

# %% [markdown]
# #### Apart from these rules, there are few naming conventions that you should follow while using this python syntax.

# %% [markdown]
# ####     1.Use uppercase initials for class names, lowercase for all others.
# #### 2. Name a private identifier with a leading underscore(_username)
# #### 3. Name a strongly private identifier with two leading underscores( __password)
# #### 4. Special identifier by Python end with two leading underscores/
