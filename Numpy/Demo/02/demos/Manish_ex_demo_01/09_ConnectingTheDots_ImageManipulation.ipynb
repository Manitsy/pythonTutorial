# %%
import numpy as np

# %%
from scipy import ndimage
from scipy import misc

# %% [markdown]
# #### We load the image of a raccoon

# %%
f = misc.face()

# %%
f.shape
# Out:
# (768, 1024, 3)

# %% [markdown]
# The first two indices represent the Y and X position of a pixel, and the third represents the RGB colour value of the pixel.

# %% [markdown]
# </n> This shows that f is a 768-by-1024 pixel image with three channels (red, green, and blue).

# %%
type(f)
# Out:
# numpy.ndarray

# %%
f
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
# ...

# %% [markdown]
# ### Displaying Images

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Display the image with the axes
# This alone won't display the image in our notebook - need to use plt.show() for that

# %%
plt.imshow(f)

# %%
plt.show()

# %% [markdown]
# ### Cropping images

# %%
a = f[384:,512:,:]

# %%
plt.imshow(a)
plt.show()

# %%
a
# Out:
# array([[[103,  99, 114],
#         [106, 104, 118],
#         [114, 112, 126],
#         ...,
#         [ 28,  37,  20],
#         [ 29,  38,  21],
#         [ 29,  38,  21]],
#
#        [[116, 113, 130],
#         [100,  97, 114],
#         [ 84,  81,  98],
#         ...,
#         [ 26,  35,  18],
#         [ 27,  36,  19],
#         [ 27,  36,  19]],
#
#        [[162, 159, 178],
#         [167, 164, 183],
#         [155, 152, 171],
#         ...,
#         [ 26,  35,  18],
#         [ 27,  36,  19],
#         [ 27,  36,  19]],
#
#        ...,
#
#        [[ 91, 134,  81],
#         [ 94, 134,  81],
#         [ 92, 131,  74],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 90, 133,  80],
#         [ 93, 133,  80],
#         [ 92, 131,  74],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 89, 132,  79],
#         [ 92, 132,  79],
#         [ 92, 131,  74],
# ...

# %%
a.shape
# Out:
# (384, 512, 3)

# %%
a1,a2 = np.split(f,2)

# %%
plt.imshow(a1)
plt.show()
plt.imshow(a2)
plt.show()

# %% [markdown]
# ### Cropping images

# %%
a = f[384:,512,:]

# %%
a
# Out:
# array([[103,  99, 114],
#        [116, 113, 130],
#        [162, 159, 178],
#        ...,
#        [ 91, 134,  81],
#        [ 90, 133,  80],
#        [ 89, 132,  79]], dtype=uint8)

# %%
plt.imshow(a)
plt.show()

# %%
a1,a2 = np.split(f,2)

# %%
a1,a2
# Out:
# (array([[[121, 112, 131],
#          [138, 129, 148],
#          [153, 144, 165],
#          ...,
#          [119, 126,  74],
#          [131, 136,  82],
#          [139, 144,  90]],
#
#         [[ 89,  82, 100],
#          [110, 103, 121],
#          [130, 122, 143],
#          ...,
#          [118, 125,  71],
#          [134, 141,  87],
#          [146, 153,  99]],
#
#         [[ 73,  66,  84],
#          [ 94,  87, 105],
#          [115, 108, 126],
#          ...,
#          [117, 126,  71],
#          [133, 142,  87],
#          [144, 153,  98]],
#
#         ...,
#
#         [[203, 233, 111],
#          [198, 228, 106],
#          [191, 223,  98],
#          ...,
#          [ 24,  36,  16],
#          [ 25,  37,  17],
#          [ 25,  37,  17]],
#
#         [[203, 233, 109],
#          [198, 228, 104],
#          [191, 223,  96],
#          ...,
#          [ 24,  36,  16],
#          [ 25,  37,  17],
#          [ 25,  37,  17]],
#
#         [[195, 225, 101],
# ...

# %%
plt.imshow(a1)
plt.show()

# %%
plt.imshow(a2)
plt.show()

# %%
b1,b2 = np.split(f,2,axis=1)

# %%
plt.imshow(b1)
plt.show()

# %%
 plt.imshow(b2)
plt.show()

# %%
plt.imshow(np.concatenate((a1,a2)))

# %% [markdown]
# By default the concatenate occurs along the horizontal axis

# %%
plt.imshow(np.concatenate((b1,b2)))

# %% [markdown]
# ##### Set the concatenation to occur along the vertical axis

# %%
plt.imshow(np.concatenate((b1,b2),axis =1))
